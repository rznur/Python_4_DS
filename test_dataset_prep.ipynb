# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

df= pd.read_csv('test.csv')

df.head(3)
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         1           NaN            0        0       B
# 1         3           NaN            0        2       B
# 2        87        4702.0            5        5       B

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.449500    36.158810
# std     4832.674037    44.179466     0.838594    19.092787    17.825287
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 9, 9

plt.scatter(df.Square,df.LifeSquare, alpha = 0.3, cmap = 'Paired') #plt.scatter(x, y....)
#plt.scatter(df,df.Price, alpha = 0.3)
plt.title("Area vs Life Area")
plt.xlabel('LifeSquare')
plt.ylabel('Square')
# Out:
# Text(0,0.5,'Square')

# %% [markdown]
# 1. same issues with LifeArea
# 2. check min Square - numbers are odd

# %%
df.loc[df['Square'] < 10]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 66     9011          53    1.0  1.378543    1.353573            1.0      1
# 608   16401          30    1.0  2.645046    4.338755            1.0      2
# 837    2138          27    1.0  5.647458    1.501582            1.0      1
# 1165  10120           6    1.0  5.100672    3.861780            1.0      3
# 4490   1165          27    1.0  2.372101    1.899119            1.0      2
# 4540   7855           6    1.0  4.967143    2.968086            1.0      3
# 4713    170           6    2.0  2.900586   61.468563            1.0     18
# 4902   1420          45    1.0  1.975769    2.900371            1.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 66           1.0       1977   0.049637         B         B        34
# 608          1.0       1977   0.000078         B         B        22
# 837          1.0       1977   0.017647         B         B         2
# ...

# %%
df.loc[(df['DistrictId'] == 53) & (df['HouseYear'] == 1977)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 5      7633          53    1.0  40.675627         NaN            1.0     21
# 66     9011          53    1.0   1.378543    1.353573            1.0      1
# 205    5060          53    2.0  55.825260         NaN            1.0      2
# 220    4766          53    1.0  42.784236         NaN            1.0     20
# 264   16378          53    2.0  57.761732         NaN            1.0     19
# 1599   2139          53    2.0  58.320798         NaN            1.0     18
# 2216   3540          53    3.0  82.358230         NaN            0.0     20
# 2222  14733          53    1.0  37.874880         NaN            1.0     15
# 2661   5894          53    1.0  40.403989         NaN            1.0     21
# 2725  15243          53    2.0  56.872925         NaN            0.0     20
# 2824  16190          53    2.0  56.594330         NaN            1.0     20
# ...

# %%
#none of the rooms have Area of 13 (if the issue is in misplaced ',')
# lets see this:
df.loc[(df['DistrictId'] == 53)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 5      7633          53    1.0   40.675627         NaN            1.0     21
# 49     6343          53    1.0   35.772276   20.554842            6.0      6
# 66     9011          53    1.0    1.378543    1.353573            1.0      1
# 94     1345          53    3.0   50.837734   38.097690            5.0      8
# 186   16500          53    2.0   57.348002   39.401492           10.0      5
# 189    8148          53    1.0   41.269606   22.627979            8.0     11
# 205    5060          53    2.0   55.825260         NaN            1.0      2
# 220    4766          53    1.0   42.784236         NaN            1.0     20
# 264   16378          53    2.0   57.761732         NaN            1.0     19
# 480   15634          53    2.0   51.764667   30.214646            6.0      2
# 487    7893          53    3.0   51.585520   33.725166            6.0      3
# ...

# %%
df.loc[(df['DistrictId'] == 53) & (df['Square'] <25)]
# Out:
#       Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 66  9011          53    1.0  1.378543    1.353573            1.0      1
#
#     HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 66         1.0       1977   0.049637         B         B        34      7759
#
#     Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 66         0         229.0            1        3       B

# %%
# train dataset also doesnt have apts in this district with area<20
#lets check other districts if it confirms will need to replace ti with a mean area for 1 room apts for this districts`
#actually we already looked at apts with are <10. all of them are weird, let's get mean

# %%
apt_area_1room_Dist53_mean = df.loc[(df['DistrictId'] == 53) & (df['Rooms']==1) & (df['Square'] >2)]['Square'].mean()
apt_area_1room_Dist53_mean
# Out:
# 38.72359491925928

# %%
df.loc[(df['DistrictId'] == 53) & (df['Square'] < 2), 'Square'] = apt_area_1room_Dist53_mean

# %%
#lets check if it changed
df.loc[(df['DistrictId'] == 53) & (df['Square'] <25)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df.loc[df['Id']==9011]
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 66  9011          53    1.0  38.723595    1.353573            1.0      1
#
#     HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 66         1.0       1977   0.049637         B         B        34      7759
#
#     Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 66         0         229.0            1        3       B

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.456969    36.158810
# std     4832.674037    44.179466     0.838594    19.078538    17.825287
# min        1.000000     0.000000     0.000000     1.975769     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df.loc[df['Square'] < 10]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 608   16401          30    1.0  2.645046    4.338755            1.0      2
# 837    2138          27    1.0  5.647458    1.501582            1.0      1
# 1165  10120           6    1.0  5.100672    3.861780            1.0      3
# 4490   1165          27    1.0  2.372101    1.899119            1.0      2
# 4540   7855           6    1.0  4.967143    2.968086            1.0      3
# 4713    170           6    2.0  2.900586   61.468563            1.0     18
# 4902   1420          45    1.0  1.975769    2.900371            1.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 608          1.0       1977   0.000078         B         B        22
# 837          1.0       1977   0.017647         B         B         2
# 1165         1.0       1977   0.243205         B         B         5
# 4490        17.0       1977   0.011654         B         B         4
# ...

# %%
df.loc[(df['DistrictId'] == 6) & (df['Square'] < 10)] # strange areas in distric 6
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 1165  10120           6    1.0  5.100672    3.861780            1.0      3
# 4540   7855           6    1.0  4.967143    2.968086            1.0      3
# 4713    170           6    2.0  2.900586   61.468563            1.0     18
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1165         1.0       1977   0.243205         B         B         5
# 4540         1.0       2018   0.243205         B         B         5
# 4713        17.0       2014   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1165      1564         0         540.0            0        0       B
# 4540      1564         0         540.0            0        0       B
# 4713      1564         0         540.0            0        0       B

# %%
df.loc[(df['DistrictId'] == 6) & (df['Rooms'] < 3)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 30     2982           6    2.0  63.460684         NaN            0.0     13
# 50    14788           6    1.0  38.269173         NaN            1.0      6
# 82    14462           6    2.0  61.610642         NaN            1.0     11
# 98    12249           6    1.0  43.286141         NaN            0.0     12
# 102   10749           6    2.0  65.582572   66.675758            1.0      4
# 121    5132           6    1.0  39.352386         NaN            1.0     12
# 128   14685           6    1.0  41.101204         NaN            0.0     12
# 134    8222           6    1.0  44.900715         NaN            0.0     15
# 147    1006           6    2.0  62.196179   35.465935           13.0      8
# 148   12271           6    2.0  62.068885         NaN            1.0      6
# 165    9596           6    2.0  54.225503         NaN            1.0     12
# ...

# %%
df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==1) & (df['HouseYear'] == 1977) & (df['Square'] > 7)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 98    12249           6    1.0  43.286141         NaN            0.0     12
# 121    5132           6    1.0  39.352386         NaN            1.0     12
# 128   14685           6    1.0  41.101204         NaN            0.0     12
# 134    8222           6    1.0  44.900715         NaN            0.0     15
# 284     256           6    1.0  38.870525   41.172814            1.0      9
# 411    2314           6    1.0  40.060487         NaN           10.0      8
# 781   12579           6    1.0  41.404390         NaN            0.0     16
# 976    8981           6    1.0  41.037707         NaN            1.0     10
# 1018  11772           6    1.0  50.659657         NaN            1.0     20
# 1169   7447           6    1.0  38.657535         NaN            1.0     12
# 1251   2770           6    1.0  47.588001         NaN            1.0      9
# ...

# %%
apt_area_1room_1977_Dis6_mean = df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==1) & (df['HouseYear'] == 1977) & (df['Square'] > 7)]['Square'].mean()
apt_area_1room_1977_Dis6_mean
# Out:
# 44.859342799581924

# %%
df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==1) & (df['Square'] < 7) & (df['HouseYear'] == 1977), 'Square'] = apt_area_1room_1977_Dis6_mean

# %%
df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==1) & (df['Square'] < 7) & (df['HouseYear'] == 1977)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df.loc[(df['DistrictId'] == 6) & (df['Square'] < 10)]
# Out:
#         Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4540  7855           6    1.0  4.967143    2.968086            1.0      3
# 4713   170           6    2.0  2.900586   61.468563            1.0     18
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4540         1.0       2018   0.243205         B         B         5
# 4713        17.0       2014   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4540      1564         0         540.0            0        0       B
# 4713      1564         0         540.0            0        0       B

# %%
df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==1) & (df['HouseYear'] == 2018) & (df['Square'] > 7)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 539   16716           6    1.0  38.515804   37.225481            7.0      2
# 4562    362           6    1.0  50.411140    5.775697            1.0     27
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 539         17.0       2018   0.243205         B         B         5
# 4562        25.0       2018   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 539       1564         0         540.0            0        0       B
# 4562      1564         0         540.0            0        0       B

# %%
#seems like ',' is misplaced for Id= 7855 in area, let's just mulitply by 10

df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==1) & (df['HouseYear'] == 2018) & (df['Square'] < 7), 'Square'] = df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==1) & (df['HouseYear'] == 2018) & (df['Square'] < 7), 'Square']*10

# %%
df.loc[(df['Id'] == 7855)]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4540  7855           6    1.0  49.671431    2.968086            1.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4540         1.0       2018   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4540      1564         0         540.0            0        0       B

# %%
df.loc[(df['DistrictId'] == 6) & (df['Square'] < 10)] # strange areas in distric 6
# Out:
#        Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4713  170           6    2.0  2.900586   61.468563            1.0     18
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4713        17.0       2014   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4713      1564         0         540.0            0        0       B

# %%
df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==2) & (df['HouseYear'] == 2014) & (df['Square'] > 10)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1932  13831           6    2.0  65.988068   60.242583            1.0     18
# 2008  10617           6    2.0  65.706387         NaN            1.0     14
# 2396  14350           6    2.0  63.954711         NaN            1.0     12
# 2777   5649           6    2.0  53.696526   14.525566            9.0     14
# 3999   7044           6    2.0  61.939638   58.028060            1.0     12
# 4162   1906           6    2.0  54.431383   32.557159            8.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1932        17.0       2014   0.243205         B         B         5
# 2008         1.0       2014   0.243205         B         B         5
# 2396         1.0       2014   0.243205         B         B         5
# 2777        17.0       2014   0.243205         B         B         5
# 3999        17.0       2014   0.243205         B         B         5
# ...

# %%
#let's get a mean, 

df.loc[(df['DistrictId'] == 6) & (df['Rooms'] ==2) & (df['HouseYear'] == 2014) & (df['Square'] > 10), 'Square'].mean()
# Out:
# 60.95278555606666

# %%
# looks like there is a typo instead of Square column area was typed into LifeSquare. lets replace

df.loc[df['Id'] == 170,  'Square' ] = df.loc[df['Id'] == 170,  'LifeSquare' ]

# %%
df.loc[(df['DistrictId'] == 6) & (df['Square'] < 10)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.485576    36.158810
# std     4832.674037    44.179466     0.838594    19.036786    17.825287
# min        1.000000     0.000000     0.000000     1.975769     0.333490
# 25%     4221.750000    21.000000     1.000000    41.923188    23.092026
# 50%     8320.500000    37.000000     2.000000    52.924953    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df.loc[df['Square'] < 10]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 608   16401          30    1.0  2.645046    4.338755            1.0      2
# 837    2138          27    1.0  5.647458    1.501582            1.0      1
# 4490   1165          27    1.0  2.372101    1.899119            1.0      2
# 4902   1420          45    1.0  1.975769    2.900371            1.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 608          1.0       1977   0.000078         B         B        22
# 837          1.0       1977   0.017647         B         B         2
# 4490        17.0       1977   0.011654         B         B         4
# 4902         1.0       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 608       6398       141        1046.0            3       23       B
# 837        469         0           NaN            0        0       B
# ...

# %%
# lets check this for Id 2138
df.loc[(df['DistrictId']==27) & (df['Rooms']==1) & (df['HouseYear']==1977) & (df['Square'] > 50)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 211   16515          27    1.0  52.692744         NaN            0.0      8
# 652    6147          27    1.0  55.739324         NaN            0.0      4
# 963    2192          27    1.0  83.353379         NaN            1.0     14
# 1502   4669          27    1.0  85.231540    5.144775            1.0      3
# 1569   2203          27    1.0  51.236004         NaN            0.0     10
# 2842  11475          27    1.0  53.263561         NaN            0.0      9
# 3084   6828          27    1.0  56.589759         NaN            0.0      7
# 3231    882          27    1.0  51.215457         NaN            1.0      4
# 3390   4033          27    1.0  51.942323         NaN            0.0     12
# 4501   3237          27    1.0  54.892848         NaN            0.0      7
# 4664   1736          27    1.0  51.492952         NaN            0.0      5
# ...

# %%
# lets check this for Id 1165

df.loc[(df['DistrictId']==27) & (df['Rooms']==1) & (df['HouseYear']==1977) & (df['Square'] < 30)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 837    2138          27    1.0   5.647458    1.501582            1.0      1
# 1436  12833          27    1.0  27.658462         NaN            0.0     10
# 4490   1165          27    1.0   2.372101    1.899119            1.0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 837          1.0       1977   0.017647         B         B         2
# 1436        19.0       1977   0.211401         B         B         9
# 4490        17.0       1977   0.011654         B         B         4
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 837        469         0           NaN            0        0       B
# 1436      1892         0           NaN            0        1       B
# 4490       915         0           NaN            0        0       B

# %%
df.loc[df['Id']== 1165, 'Square'] = df.loc[df['Id']== 1165, 'Square']*10 
df.loc[df['Id']== 2138, 'Square'] = df.loc[df['Id']== 2138, 'Square']*10

# %%
df.loc[df['Id']== 1165]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4490  1165          27    1.0  23.721005    1.899119            1.0      2
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4490        17.0       1977   0.011654         B         B         4
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4490       915         0           NaN            0        0       B

# %%
df.loc[df['Id']== 2138]
# Out:
#        Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 837  2138          27    1.0  56.474584    1.501582            1.0      1
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 837         1.0       1977   0.017647         B         B         2       469
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 837         0           NaN            0        0       B

# %%
df.loc[df['Square'] < 10]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 608   16401          30    1.0  2.645046    4.338755            1.0      2
# 4902   1420          45    1.0  1.975769    2.900371            1.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 608          1.0       1977   0.000078         B         B        22
# 4902         1.0       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 608       6398       141        1046.0            3       23       B
# 4902      5212         6           NaN            3        2       B

# %%
df.loc[(df['DistrictId']==30) & (df['Rooms']==1) & (df['HouseYear']==1977) & (df['Square'] >10)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 113    5032          30    1.0  50.738045         NaN            0.0      5
# 349   13978          30    1.0  39.877152         NaN            1.0     18
# 532   15265          30    1.0  46.183583   48.806486            0.0      4
# 1084   8086          30    1.0  38.599746         NaN            1.0     12
# 1184  11371          30    1.0  37.862956         NaN            1.0      8
# 1701  14935          30    1.0  49.387306         NaN            1.0     14
# 1721   6345          30    1.0  38.772397         NaN            1.0      5
# 1848   8971          30    1.0  43.067027   43.098980            1.0      5
# 2155   5308          30    1.0  39.334911         NaN            1.0     18
# 2212   5619          30    1.0  45.549753   43.339850            1.0      9
# 2223  10609          30    1.0  44.431455         NaN            1.0     21
# ...

# %%
# seems like area with misplaced into life area for 16401
# and need to multiply by 10

# %%
df.Square, df.LifeSquare = np.where(df['Id'] == 16401, [df.LifeSquare*10, df.Square*10], [df.Square, df.LifeSquare])

# %%
df.loc[df['Id'] == 16401]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 608  16401          30    1.0  43.387555   26.450465            1.0      2
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 608         1.0       1977   0.000078         B         B        22      6398
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 608       141        1046.0            3       23       B

# %%
df.loc[df['Square'] < 10]
# Out:
#         Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4902  1420          45    1.0  1.975769    2.900371            1.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4902         1.0       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4902      5212         6           NaN            3        2       B

# %%
df.loc[(df['DistrictId']==45) & (df['Rooms']==1) & (df['HouseYear']==1977) & (df['Square'] >10)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 46    12309          45    1.0  42.899569         NaN            0.0     25
# 176   12025          45    1.0  39.353898         NaN            1.0     17
# 595   10226          45    1.0  43.832770         NaN            1.0     16
# 1174  11165          45    1.0  39.529917   41.892823            1.0     20
# 1781   8010          45    1.0  39.219980         NaN            0.0     22
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 46           0.0       1977   0.195781         B         B        23
# 176          1.0       1977   0.195781         B         B        23
# 595          1.0       1977   0.195781         B         B        23
# 1174        25.0       1977   0.195781         B         B        23
# 1781         0.0       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %%
df.Square, df.LifeSquare = np.where(df['Id'] == 11165, [df.LifeSquare, df.Square], [df.Square, df.LifeSquare])

# %%
df.loc[(df['DistrictId']==45) & (df['Rooms']==1) & (df['HouseYear']==1977) & (df['Square'] >10)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 46    12309          45    1.0  42.899569         NaN            0.0     25
# 176   12025          45    1.0  39.353898         NaN            1.0     17
# 595   10226          45    1.0  43.832770         NaN            1.0     16
# 1174  11165          45    1.0  41.892823   39.529917            1.0     20
# 1781   8010          45    1.0  39.219980         NaN            0.0     22
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 46           0.0       1977   0.195781         B         B        23
# 176          1.0       1977   0.195781         B         B        23
# 595          1.0       1977   0.195781         B         B        23
# 1174        25.0       1977   0.195781         B         B        23
# 1781         0.0       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# ...

# %%
# in train dataset we have apt with area = 29.seems like are was misplaced with life are, and need to multiply by 10 too

df.Square, df.LifeSquare = np.where(df['Id'] == 1420, [df.LifeSquare*10, df.Square*10], [df.Square, df.LifeSquare])

# %%
df.loc[(df['Id']==1420)]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4902  1420          45    1.0  29.003714   19.757689            1.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4902         1.0       1977   0.195781         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4902      5212         6           NaN            3        2       B

# %%
df.loc[df['Square'] < 10]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.514037    36.168057
# std     4832.674037    44.179466     0.838594    18.987012    17.812688
# min        1.000000     0.000000     0.000000    13.305531     0.333490
# 25%     4221.750000    21.000000     1.000000    41.926034    23.095345
# 50%     8320.500000    37.000000     2.000000    52.928839    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# ...

# %%
#LifeSquar is useless, drop in train dataset
# let check Kitchensquare and still lifesquare, in case it was misplaced with sqaure

# %%
df.loc[df['KitchenSquare']>600]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1964  14594          11    2.0  42.795304    24.22377          620.0     11
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1964        14.0       1972   0.038693         B         B        28
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1964      6533         1        1015.0            2        5       B

# %%
df.loc[df['KitchenSquare']>600, 'KitchenSquare'] = df.loc[df['KitchenSquare']>600, 'KitchenSquare']/100
df.loc[df['Id'] == 14594]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1964  14594          11    2.0  42.795304    24.22377            6.2     11
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1964        14.0       1972   0.038693         B         B        28
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1964      6533         1        1015.0            2        5       B

# %%
df.loc[df['KitchenSquare']>600]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2]
# Index: []

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.514037    36.168057
# std     4832.674037    44.179466     0.838594    18.987012    17.812688
# min        1.000000     0.000000     0.000000    13.305531     0.333490
# 25%     4221.750000    21.000000     1.000000    41.926034    23.095345
# 50%     8320.500000    37.000000     2.000000    52.928839    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count     5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean         5.85404     8.632000    12.601000  1984.392600     0.119874
# std          4.85467     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df.loc[df['KitchenSquare']>100]
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1777  3341          62    3.0  112.114019  112.247841          112.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1777         3.0       2017   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1777       629         1           NaN            0        0       A

# %%
df.Square, df.LifeSquare = np.where(df['Id'] == 3341, [df.LifeSquare, df.Square], [df.Square, df.LifeSquare])

# %%
df.loc[df['KitchenSquare']>100]
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1777  3341          62    3.0  112.247841  112.114019          112.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1777         3.0       2017   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1777       629         1           NaN            0        0       A

# %%
df.loc[df['KitchenSquare']<1]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 22    12694          27    3.0   83.670032   46.358356            0.0      8
# 24     8968          27    2.0   69.849239         NaN            0.0      3
# 30     2982           6    2.0   63.460684         NaN            0.0     13
# 32     2449           1    1.0   66.426585         NaN            0.0     14
# 43    11513           1    1.0   37.484057   40.593036            0.0      4
# 46    12309          45    1.0   42.899569         NaN            0.0     25
# 78     6553          34    5.0  122.375273    0.333490            0.0      9
# 97    12499           6    3.0   81.725331         NaN            0.0     10
# 98    12249           6    1.0   43.286141         NaN            0.0     12
# 101    7848           1    2.0   63.820166         NaN            0.0      3
# 110    3103           1    3.0   81.680369         NaN            0.0      6
# ...

# %%
#KitchenSquare seems weird here, but same happens in train dataset. just not use Kitchen square in the model

# %%
#meanwhile let fix this issue for all:
df.Square, df.LifeSquare = np.where(df['LifeSquare']>df['Square'], [df.LifeSquare, df.Square], [df.Square, df.LifeSquare])

# %%
df.loc[df['KitchenSquare']<1]
#DO NOT USE KITCHENSQUARE IN THE MODEL
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 22    12694          27    3.0   83.670032   46.358356            0.0      8
# 24     8968          27    2.0   69.849239         NaN            0.0      3
# 30     2982           6    2.0   63.460684         NaN            0.0     13
# 32     2449           1    1.0   66.426585         NaN            0.0     14
# 43    11513           1    1.0   40.593036   37.484057            0.0      4
# 46    12309          45    1.0   42.899569         NaN            0.0     25
# 78     6553          34    5.0  122.375273    0.333490            0.0      9
# 97    12499           6    3.0   81.725331         NaN            0.0     10
# 98    12249           6    1.0   43.286141         NaN            0.0     12
# 101    7848           1    2.0   63.820166         NaN            0.0      3
# 110    3103           1    3.0   81.680369         NaN            0.0      6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       3959 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Ecology_2        5000 non-null object
# Ecology_3        5000 non-null object
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     2623 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# Shops_2          5000 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 742.3+ KB

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.643051    36.005120
# std     4832.674037    44.179466     0.838594    19.319484    17.161786
# min        1.000000     0.000000     0.000000    13.305531     0.333490
# 25%     4221.750000    21.000000     1.000000    42.023090    23.095345
# 50%     8320.500000    37.000000     2.000000    52.957761    32.892831
# 75%    12598.250000    77.000000     2.000000    66.416189    45.083374
# max    16795.000000   212.000000    17.000000   303.071094   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count     5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean         5.85404     8.632000    12.601000  1984.392600     0.119874
# std          4.85467     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df.loc[df['Rooms']>9]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3398  1435         111   17.0  52.866107   32.528342            8.0     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3398        17.0       1987   0.093443         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3398      4635         5        3300.0            2        4       B

# %%
#weird # of rooms, probably 1 or 2 rooms. lets see in DistrictId 111

# %%
df.loc[df['DistrictId']==111]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 139   15371         111    2.0  63.652074   32.039183           12.0     15
# 166    5317         111    1.0  38.828270   23.493251            7.0     16
# 299    6190         111    1.0  34.126319   33.138594            5.0      5
# 493    8617         111    1.0  41.063553   24.843986            8.0      9
# 578    3051         111    3.0  63.562296   45.510579            5.0      5
# 742    6320         111    3.0  60.905888   40.314752            5.0      7
# 861    3681         111    3.0  79.434939   53.210317            8.0      6
# 909     781         111    1.0  35.907781   20.347566            6.0      6
# 997    9627         111    3.0  63.793512   47.792375            5.0      5
# 1069  16422         111    2.0  45.561872   30.098828            5.0      6
# 1071   2922         111    1.0  39.172504   22.666167           10.0     21
# ...

# %%
# seems like it should be a 2 bedroom

df.loc[df['Id']==1435, 'Rooms'] = 2

# %%
df.loc[df['Id']==1435]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3398  1435         111    2.0  52.866107   32.528342            8.0     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3398        17.0       1987   0.093443         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3398      4635         5        3300.0            2        4       B

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.907000    56.643051    36.005120
# std     4832.674037    44.179466     0.810976    19.319484    17.161786
# min        1.000000     0.000000     0.000000    13.305531     0.333490
# 25%     4221.750000    21.000000     1.000000    42.023090    23.095345
# 50%     8320.500000    37.000000     2.000000    52.957761    32.892831
# 75%    12598.250000    77.000000     2.000000    66.416189    45.083374
# max    16795.000000   212.000000     6.000000   303.071094   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count     5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean         5.85404     8.632000    12.601000  1984.392600     0.119874
# std          4.85467     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df.loc[df['Square'] <15]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3697  15435          21    1.0  13.305531    9.495367            0.0      6
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3697         5.0       1965   0.194489         B         B        47
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3697      8004         3         125.0            3        5       B

# %%
#in the final training dataset i used bins from 15 sq.m, so let's round this num to 15...

# %%
df.loc[df['Id']==15435, 'Square'] = 15.01

# %%
df.loc[df['Id']==15435]
# Out:
#          Id  DistrictId  Rooms  Square  LifeSquare  KitchenSquare  Floor  \
# 3697  15435          21    1.0   15.01    9.495367            0.0      6
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3697         5.0       1965   0.194489         B         B        47
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 3697      8004         3         125.0            3        5       B

# %%
df.loc[df['Square'] >279]
# Out:
#         Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 410  11533          94    2.0  303.071094   48.713443            6.0      5
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 410        12.0       1974   0.521867         B         B        25      6149
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 410         0           NaN            0        0       B

# %%
#smth is wrong here...

# %%
df.loc[df['DistrictId'] == 94]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 258    3286          94    1.0   32.646326   20.946963            6.0     10
# 386   13258          94    1.0   32.815336   22.544629            6.0      6
# 410   11533          94    2.0  303.071094   48.713443            6.0      5
# 415    2008          94    2.0   48.693296   32.258703            5.0      7
# 609   11913          94    1.0   32.785698   18.104429            6.0      9
# 751    3932          94    1.0   34.344898   21.173682            6.0      3
# 792    6989          94    1.0   45.650801   17.178724           10.0     18
# 1100  11730          94    2.0   44.191358   28.031866            6.0      5
# 1173   1457          94    2.0   57.972175   33.424595            9.0      9
# 1306   3043          94    2.0   58.821104   34.173374            9.0     17
# 1344  10365          94    1.0   37.753364   19.350202            9.0     12
# ...

# %%
#looks like it should be in 30s, lets fix the typo

# %%
df.loc[df['Id']==11533, 'Square'] = df.loc[df['Id']==11533, 'Square']/10

# %%
df.loc[df['Id']==11533]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 410  11533          94    2.0  30.307109   48.713443            6.0      5
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 410        12.0       1974   0.521867         B         B        25      6149
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 410         0           NaN            0        0       B

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.907000    56.588839    36.005120
# std     4832.674037    44.179466     0.810976    19.005302    17.161786
# min        1.000000     0.000000     0.000000    15.010000     0.333490
# 25%     4221.750000    21.000000     1.000000    42.015628    23.095345
# 50%     8320.500000    37.000000     2.000000    52.933734    32.892831
# 75%    12598.250000    77.000000     2.000000    66.392939    45.083374
# max    16795.000000   212.000000     6.000000   223.453689   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count     5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean         5.85404     8.632000    12.601000  1984.392600     0.119874
# std          4.85467     5.483228     6.789213    18.573149     0.120070
# ...

# %%
df.loc[df['Floor']==78]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4698  15759          17    2.0  57.60187   37.744743           10.0     78
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4698        22.0       1989        0.0         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4698      5027         4          46.0            1        1       B

# %%
df.loc[(df['DistrictId']==17)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 345   11295          17    2.0   57.070222   35.874576            9.0      2
# 761   10448          17    3.0   79.719735   50.855106           10.0      6
# 839   15960          17    3.0   67.730891   47.372408            8.0      8
# 1266   8159          17    3.0   80.256534   58.155110           10.0      8
# 1297  13966          17    2.0   65.457987   37.499968           11.0      7
# 1338  14108          17    1.0   32.233328   20.974668            7.0      7
# 1632  15284          17    1.0   35.943568   23.834555            5.0      3
# 1780  11576          17    2.0   54.680906   39.010163            8.0      4
# 1867  13367          17    2.0   56.673044   40.753327            8.0      2
# 1961  16228          17    1.0  121.453559   87.521642           17.0     17
# 2047  15339          17    1.0   34.691517   20.531955            6.0      9
# ...

# %%
#seems like some houses with 22 floors, may be a typo. let's put 7 (first number from 78)

df.loc[df['Id']==15759, 'Floor'] = 7

# %%
df.loc[df['Id']== 15759]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4698  15759          17    2.0  57.60187   37.744743           10.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4698        22.0       1989        0.0         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4698      5027         4          46.0            1        1       B

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
# Id               5000 non-null int64
# DistrictId       5000 non-null int64
# Rooms            5000 non-null float64
# Square           5000 non-null float64
# LifeSquare       3959 non-null float64
# KitchenSquare    5000 non-null float64
# Floor            5000 non-null int64
# HouseFloor       5000 non-null float64
# HouseYear        5000 non-null int64
# Ecology_1        5000 non-null float64
# Ecology_2        5000 non-null object
# Ecology_3        5000 non-null object
# Social_1         5000 non-null int64
# Social_2         5000 non-null int64
# Social_3         5000 non-null int64
# Healthcare_1     2623 non-null float64
# Helthcare_2      5000 non-null int64
# Shops_1          5000 non-null int64
# Shops_2          5000 non-null object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 742.3+ KB

# %%
#df = df.drop(['Healthcare_1', 'Social_1','Social_2','Social_3', 'Shops_1', 'Shops_2', 'Ecology_1', 'Ecology_2', 'Ecology_3'], axis = 1)

'''Square               10000 non-null float64
Floor                10000 non-null float64
HouseFloor           10000 non-null float64
Helthcare_2          10000 non-null int64
Price                10000 non-null float64
mean_price_x         10000 non-null float64
mean_price_y         10000 non-null float64
mean_price_floor     10000 non-null float64
mean_price_year      10000 non-null float64
mean_price_distr     10000 non-null float64
mean_price_health    10000 non-null float64
'''
# Out:
# 'Square               10000 non-null float64\nFloor                10000 non-null float64\nHouseFloor           10000 non-null float64\nHelthcare_2          10000 non-null int64\nPrice                10000 non-null float64\nmean_price_x         10000 non-null float64\nmean_price_y         10000 non-null float64\nmean_price_floor     10000 non-null float64\nmean_price_year      10000 non-null float64\nmean_price_distr     10000 non-null float64\nmean_price_health    10000 non-null float64\n'

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.907000    56.588839    36.005120
# std     4832.674037    44.179466     0.810976    19.005302    17.161786
# min        1.000000     0.000000     0.000000    15.010000     0.333490
# 25%     4221.750000    21.000000     1.000000    42.015628    23.095345
# 50%     8320.500000    37.000000     2.000000    52.933734    32.892831
# 75%    12598.250000    77.000000     2.000000    66.392939    45.083374
# max    16795.000000   212.000000     6.000000   223.453689   168.729035
#
#        KitchenSquare       Floor   HouseFloor    HouseYear    Ecology_1  \
# count     5000.00000  5000.00000  5000.000000  5000.000000  5000.000000
# mean         5.85404     8.61780    12.601000  1984.392600     0.119874
# std          4.85467     5.39477     6.789213    18.573149     0.120070
# ...

# %%
df.loc[df['HouseFloor']==99]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 651  15864          27    3.0  47.722835   47.098813            9.0     18
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 651        99.0       1977   0.072158         B         B         2       629
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 651         1           NaN            0        0       A

# %%
df.loc[(df['DistrictId']==27) & (df['HouseYear']==1977) ]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 14     5214          27    1.0   37.555197         NaN            1.0      5
# 24     8968          27    2.0   69.849239         NaN            0.0      3
# 40     5428          27    2.0   62.326044         NaN           61.0     12
# 59    10614          27    1.0   44.254995         NaN            1.0      3
# 89     5438          27    2.0   67.069295         NaN            1.0      5
# 120   12743          27    1.0   40.407390         NaN            0.0      9
# 132   14834          27    3.0   56.310351         NaN            0.0     19
# 164   14320          27    1.0   39.449663         NaN            0.0      8
# 211   16515          27    1.0   52.692744         NaN            0.0      8
# 245   12212          27    2.0   69.239091         NaN           10.0     16
# 301    9224          27    2.0   54.236730         NaN            1.0     13
# ...

# %%
df.HouseFloor, df.Floor = np.where(df.HouseFloor < df.Floor, [df.Floor, df.HouseFloor], [df.HouseFloor, df.Floor])

# %%
df.loc[(df['DistrictId']==27) & (df['HouseYear']==1977)& (df['HouseFloor']>17)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 132   14834          27    3.0  56.310351         NaN            0.0    0.0
# 164   14320          27    1.0  39.449663         NaN            0.0    8.0
# 373    5381          27    2.0  59.358270   56.896136            8.0   17.0
# 475    2346          27    3.0  81.432451         NaN            0.0   12.0
# 512    1633          27    1.0  34.098012         NaN            1.0   10.0
# 543    5476          27    1.0  43.739878   42.081012            1.0   19.0
# 651   15864          27    3.0  47.722835   47.098813            9.0   18.0
# 657   14976          27    1.0  37.548156         NaN            1.0   19.0
# 686    5298          27    2.0  62.831445         NaN            0.0    6.0
# 785     591          27    3.0  49.543826         NaN            0.0   20.0
# 919     310          27    3.0  49.883368   45.411358            0.0   18.0
# ...

# %%
df.loc[(df['DistrictId']==27) & (df['HouseYear']==1977)& (df['HouseFloor']>17)].drop(labels=651)['HouseFloor'].mean()
# Out:
# 21.2

# %%
df.loc[df['Id']==15864, 'HouseFloor'] = round(df.loc[(df['DistrictId']==27) & (df['HouseYear']==1977)& (df['HouseFloor']>17)].drop(labels=651)['HouseFloor'].mean())

# %%
df.loc[df['Id']==15864]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 651  15864          27    3.0  47.722835   47.098813            9.0   18.0
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 651        21.0       1977   0.072158         B         B         2       629
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 651         1           NaN            0        0       A

# %%
df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.907000    56.588839    36.005120
# std     4832.674037    44.179466     0.810976    19.005302    17.161786
# min        1.000000     0.000000     0.000000    15.010000     0.333490
# 25%     4221.750000    21.000000     1.000000    42.015628    23.095345
# 50%     8320.500000    37.000000     2.000000    52.933734    32.892831
# 75%    12598.250000    77.000000     2.000000    66.392939    45.083374
# max    16795.000000   212.000000     6.000000   223.453689   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count     5000.00000  5000.000000  5000.000000  5000.000000  5000.000000
# mean         5.85404     7.835000    13.368200  1984.392600     0.119874
# std          4.85467     5.451323     6.046647    18.573149     0.120070
# ...

# %%
df = df.drop(['LifeSquare', 'KitchenSquare'], axis = 1)

# %%
df.to_pickle('test_cleaned.pkl')

# %%
df.loc[df['Rooms']==0]
# Out:
#          Id  DistrictId  Rooms      Square  Floor  HouseFloor  HouseYear  \
# 2406   3343          58    0.0  116.824201    3.0         3.0       1977
# 2524  10729          27    0.0   76.345154    0.0        14.0       1977
#
#       Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 2406   0.437885         B         B        23      5735         3
# 2524   0.017647         B         B         2       469         0
#
#       Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 2406        1084.0            0        5       B
# 2524           NaN            0        0       B

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
# Id              5000 non-null int64
# DistrictId      5000 non-null int64
# Rooms           5000 non-null float64
# Square          5000 non-null float64
# Floor           5000 non-null float64
# HouseFloor      5000 non-null float64
# HouseYear       5000 non-null int64
# Ecology_1       5000 non-null float64
# Ecology_2       5000 non-null object
# Ecology_3       5000 non-null object
# Social_1        5000 non-null int64
# Social_2        5000 non-null int64
# Social_3        5000 non-null int64
# Healthcare_1    2623 non-null float64
# Helthcare_2     5000 non-null int64
# Shops_1         5000 non-null int64
# Shops_2         5000 non-null object
# dtypes: float64(6), int64(8), object(3)
# memory usage: 664.1+ KB
